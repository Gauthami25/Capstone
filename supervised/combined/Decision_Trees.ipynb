# %%
import pandas as pd

# %%
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('/Users/gauthamiaithal/Local_Documents/MS DS/Spring 23/Text Mining/Data Extraction/News/supervised/combined/final_combined.csv')

# %%
df.head()
# Out:
#                                          Description     Label
# 0  renewables are already producing more energy t...  Positive
# 1  nuclear row looms over eu renewable energy tal...  Positive
# 2  ges investors seek solutions to renewable ener...  Positive
# 3  eu plans subsidies for hydrogen made using ren...  Positive
# 4  germany spain push to keep nuclear out of eu r...  Positive

# %%
X = df['Description']
Y = df['Label']

# %%
X2_train, X2_test, Y2_train, Y2_test = train_test_split(X,
                                                        Y,
                                                        stratify = Y,
                                                        test_size = 0.2,
                                                        random_state = 42)

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer()
vectorizer.fit(X2_train)

training_vectorizer = vectorizer.transform(X2_train)

# %%
testing_vectorizer = vectorizer.transform(X2_test)

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# %%
# decision trees
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.naive_bayes import MultinomialNB
# import time
kfold = KFold(n_splits = 10)

# model_mnb = MultinomialNB()

# results = cross_val_score(model_mnb, training_vectorizer, Y2_train, cv=kfold)

dt = DecisionTreeClassifier(max_depth=3)
results_dt = cross_val_score(dt, training_vectorizer, Y2_train, cv=kfold)

# %%
dt.fit(training_vectorizer, Y2_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
Y_train_prediction = dt.predict(training_vectorizer)

# %%
Y_test_prediction = dt.predict(testing_vectorizer)

# %%
from sklearn import tree
import matplotlib.pyplot as plt, seaborn as sns
text_representation = tree.export_text(dt)
print(text_representation)

X = training_vectorizer
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(dt,
                   feature_names=vectorizer.get_feature_names_out(),
                   class_names=['Positive', "Negative"],
                   filled=True)
# Out:
# |--- feature_896 <= 0.50
# |   |--- feature_3703 <= 0.50
# |   |   |--- feature_1612 <= 0.50
# |   |   |   |--- class: Negative
# |   |   |--- feature_1612 >  0.50
# |   |   |   |--- class: Positive
# |   |--- feature_3703 >  0.50
# |   |   |--- class: Positive
# |--- feature_896 >  0.50
# |   |--- feature_808 <= 0.50
# |   |   |--- feature_4255 <= 0.50
# |   |   |   |--- class: Positive
# |   |   |--- feature_4255 >  0.50
# |   |   |   |--- class: Negative
# |   |--- feature_808 >  0.50
# |   |   |--- class: Negative

# %%
dt_4 = DecisionTreeClassifier(max_depth=4)
dt_4.fit(training_vectorizer, Y2_train)
from sklearn import tree
import matplotlib.pyplot as plt, seaborn as sns
text_representation = tree.export_text(dt_4)

print(text_representation)

X = training_vectorizer
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(dt_4,
                   feature_names=vectorizer.get_feature_names_out(),
                   class_names=['Positive', "Negative"],
                   filled=True)
# Out:
# |--- feature_896 <= 0.50
# |   |--- feature_3703 <= 0.50
# |   |   |--- feature_1612 <= 0.50
# |   |   |   |--- feature_1280 <= 0.50
# |   |   |   |   |--- class: Negative
# |   |   |   |--- feature_1280 >  0.50
# |   |   |   |   |--- class: Positive
# |   |   |--- feature_1612 >  0.50
# |   |   |   |--- feature_3248 <= 0.50
# |   |   |   |   |--- class: Positive
# |   |   |   |--- feature_3248 >  0.50
# |   |   |   |   |--- class: Negative
# |   |--- feature_3703 >  0.50
# |   |   |--- class: Positive
# |--- feature_896 >  0.50
# |   |--- feature_2462 <= 0.50
# |   |   |--- feature_1677 <= 0.50
# |   |   |   |--- feature_5232 <= 0.50
# |   |   |   |   |--- class: Positive
# |   |   |   |--- feature_5232 >  0.50
# |   |   |   |   |--- class: Negative
# |   |   |--- feature_1677 >  0.50
# |   |   |   |--- class: Negative
# |   |--- feature_2462 >  0.50
# |   |   |--- class: Negative

# %%
dt_5 = DecisionTreeClassifier(max_depth=5)
dt_5.fit(training_vectorizer, Y2_train)
from sklearn import tree
import matplotlib.pyplot as plt, seaborn as sns
text_representation = tree.export_text(dt_5)

print(text_representation)

X = training_vectorizer
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(dt_5,
                   feature_names=vectorizer.get_feature_names_out(),
                   class_names=['Positive', "Negative"],
                   filled=True)
# Out:
# |--- feature_896 <= 0.50
# |   |--- feature_3703 <= 0.50
# |   |   |--- feature_1612 <= 0.50
# |   |   |   |--- feature_1280 <= 0.50
# |   |   |   |   |--- feature_737 <= 0.50
# |   |   |   |   |   |--- class: Negative
# |   |   |   |   |--- feature_737 >  0.50
# |   |   |   |   |   |--- class: Positive
# |   |   |   |--- feature_1280 >  0.50
# |   |   |   |   |--- class: Positive
# |   |   |--- feature_1612 >  0.50
# |   |   |   |--- feature_3248 <= 0.50
# |   |   |   |   |--- class: Positive
# |   |   |   |--- feature_3248 >  0.50
# |   |   |   |   |--- class: Negative
# |   |--- feature_3703 >  0.50
# |   |   |--- class: Positive
# |--- feature_896 >  0.50
# |   |--- feature_2892 <= 0.50
# |   |   |--- feature_3544 <= 0.50
# |   |   |   |--- feature_5176 <= 0.50
# |   |   |   |   |--- class: Positive
# |   |   |   |--- feature_5176 >  0.50
# |   |   |   |   |--- class: Negative
# |   |   |--- feature_3544 >  0.50
# |   |   |   |--- class: Negative
# |   |--- feature_2892 >  0.50
# |   |   |--- class: Negative

# %%
# calculate score for predicted data against testing data
from sklearn import metrics

# compare predicted resultset with the test set
metrics.accuracy_score(Y2_test, Y_test_prediction)
# Out:
# 0.6962025316455697

# %%
# calculate score for predicted data against training data

metrics.accuracy_score(Y2_train, Y_train_prediction)
# Out:
# 0.7201907790143084

# %%
# Calculate confusion matrix

metrics.confusion_matrix(Y2_test, Y_test_prediction)
# Out:
# array([[77,  1],
#        [47, 33]])

# %%
from sklearn.metrics import classification_report
print(classification_report(Y2_train, Y_train_prediction, target_names=['Positive', 'Negative']))
# Out:
#               precision    recall  f1-score   support
#
#     Positive       0.64      0.99      0.78       312
#     Negative       0.99      0.45      0.62       317
#
#     accuracy                           0.72       629
#    macro avg       0.81      0.72      0.70       629
# weighted avg       0.81      0.72      0.70       629

# %%
dt = DecisionTreeClassifier(max_depth=3)
dt.fit(training_vectorizer, Y2_train)
Y_train_prediction = dt.predict(training_vectorizer)
Y_test_prediction = dt.predict(testing_vectorizer)
print(f'Training accuracy: {metrics.accuracy_score(Y2_train, Y_train_prediction)}')
print(f'Testing accuracy: {metrics.accuracy_score(Y2_test, Y_test_prediction)}')
print(f'Confusion Matrix: \n {metrics.confusion_matrix(Y2_test, Y_test_prediction)}')
print(classification_report(Y2_train, Y_train_prediction, target_names=['Positive', 'Negative']))
# Out:
# Training accuracy: 0.7201907790143084
# Testing accuracy: 0.6962025316455697
# Confusion Matrix:
#  [[77  1]
#  [47 33]]
#               precision    recall  f1-score   support
#
#     Positive       0.64      0.99      0.78       312
#     Negative       0.99      0.45      0.62       317
#
#     accuracy                           0.72       629
#    macro avg       0.81      0.72      0.70       629
# weighted avg       0.81      0.72      0.70       629

# %%
dt_4 = DecisionTreeClassifier(max_depth=4)
dt_4.fit(training_vectorizer, Y2_train)
Y_train_prediction = dt_4.predict(training_vectorizer)
Y_test_prediction = dt_4.predict(testing_vectorizer)
print(f'Training accuracy: {metrics.accuracy_score(Y2_train, Y_train_prediction)}')
print(f'Testing accuracy: {metrics.accuracy_score(Y2_test, Y_test_prediction)}')
print(f'Confusion Matrix: \n {metrics.confusion_matrix(Y2_test, Y_test_prediction)}')
print(classification_report(Y2_train, Y_train_prediction, target_names=['Positive', 'Negative']))
# Out:
# Training accuracy: 0.7456279809220986
# Testing accuracy: 0.7341772151898734
# Confusion Matrix:
#  [[77  1]
#  [41 39]]
#               precision    recall  f1-score   support
#
#     Positive       0.66      1.00      0.80       312
#     Negative       1.00      0.50      0.66       317
#
#     accuracy                           0.75       629
#    macro avg       0.83      0.75      0.73       629
# weighted avg       0.83      0.75      0.73       629

# %%
dt_5 = DecisionTreeClassifier(max_depth=5)
dt_5.fit(training_vectorizer, Y2_train)
Y_train_prediction = dt_5.predict(training_vectorizer)
Y_test_prediction = dt_5.predict(testing_vectorizer)
print(f'Training accuracy: {metrics.accuracy_score(Y2_train, Y_train_prediction)}')
print(f'Testing accuracy: {metrics.accuracy_score(Y2_test, Y_test_prediction)}')
print(f'Confusion Matrix: \n {metrics.confusion_matrix(Y2_test, Y_test_prediction)}')
print(classification_report(Y2_train, Y_train_prediction, target_names=['Positive', 'Negative']))
# Out:
# Training accuracy: 0.7678855325914149
# Testing accuracy: 0.7468354430379747
# Confusion Matrix:
#  [[77  1]
#  [39 41]]
#               precision    recall  f1-score   support
#
#     Positive       0.68      1.00      0.81       312
#     Negative       0.99      0.54      0.70       317
#
#     accuracy                           0.77       629
#    macro avg       0.84      0.77      0.76       629
# weighted avg       0.84      0.77      0.76       629
